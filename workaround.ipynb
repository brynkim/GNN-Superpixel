# %%
import pandas as pd

# %%
df = pd.read_pickle('./converted/train/data0000.pkl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_pickle('./converted/train/data0000.pkl')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/pickle.py:179, in read_pickle(filepath_or_buffer, compression, storage_options)
#     115 """
#     116 Load pickled pandas object (or any object) from file.
#     117
#    (...)
#     176 4    4    9
#     177 """
#     178 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 179 with get_handle(
#     180     filepath_or_buffer,
#     181     "rb",
#     182     compression=compression,
#     183     is_text=False,
#     184     storage_options=storage_options,
#     185 ) as handles:
#     186     # 1) try standard library Pickle
#     187     # 2) try pickle_compat (older pandas version) to handle subclass changes
# ...

# %%
df

# %%
df.columns

# %%
df['slic_rgb_global_graph'][0]

# %%
df['slic_rgb_local_graph'][0]

# %%
df['slic_rgb_global_graph'][0].nodes(data = True)[0]

# %%
list(df['slic_rgb_global_graph'][0].edges(data = True))[0:5]

# %%
df['slic_rgb_local_graph'][0][0].nodes(data = True)

# %%
df['slic_rgb_local_graph'][0][0].edges(data = True)

# %%
import os
import pandas as pd

# %%
df = pd.read_csv('./name.csv', delimiter = '\t')

# %%
df['directory'] = sorted(os.listdir('./ImageNet/train'))

# %%
df[350:400]
# Out:
#      Class ID                                         Class Name  directory
# 350       350                                   ibex, Capra ibex  n02417914
# 351       351                                         hartebeest  n02422106
# 352       352                         impala, Aepyceros melampus  n02422699
# 353       353                                            gazelle  n02423022
# 354       354      Arabian camel, dromedary, Camelus dromedarius  n02437312
# 355       355                                              llama  n02437616
# 356       356                                             weasel  n02441942
# 357       357                                               mink  n02442845
# 358       358  polecat, fitch, foulmart, foumart, Mustela put...  n02443114
# 359       359      black-footed ferret, ferret, Mustela nigripes  n02443484
# 360       360                                              otter  n02444819
# ...

# %%
df[df['Class Name'] == 'Pomeranian']
# Out:
#      Class ID  Class Name  directory
# 259       259  Pomeranian  n02112018
